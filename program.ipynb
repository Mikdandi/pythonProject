# %% [raw]
# ---
# title: Task
# description: Select data from computer
# show-code: False
# params:
#     filename:
#         label: Select file to analize
#         input: file
#         maxFileSize: 2MB
#     legendVar:
#         label: This is checkbox label
#         input: checkbox
#         value: False
#     whatToFind:
#         input: text
#         label: What to find
#         value: What to find
#         rows:
#     valueOfWhatToFind:
#         input: text
#         label: value of what to find
#         value: first parametr
#         rows:
#     firstVar:
#         input: text
#         label: Enter first parametr(y on graph)
#         value: first parametr
#         rows:
#     secondVar:
#         input: text
#         label: Enter second parametr(x on graph)
#         value: second parametr
#         rows:
# ---

# %%
import mercury as mr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
filename='heathrowDataFiltered.csv'
whatToFind='Year'
valueOfWhatToFind=1980
legendVar=False
firstVar='Tmax'
secondVar='Month'

# %%
import matplotlib.pyplot as plt
import pandas as pd
weather=pd.read_csv(filename)
weather[weather[whatToFind]==int(valueOfWhatToFind)].plot(y=firstVar, x=secondVar,legend=legendVar)
print(f"Result when {whatToFind} is {valueOfWhatToFind}")
# Out:
# Result when Year is 1980
